# %% [markdown]
# ## Pandas Filtering Data

# %%
import pandas as pd
houses = pd.read_csv("data/kc_house_data.csv")
titanic = pd.read_csv("data/titanic.csv")
netflix = pd.read_csv("data/netflix_titles.csv", sep="|", index_col=0)

# %%
df = titanic.head()
df
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
df.sex
# Out:
# 0    female
# 1      male
# 2    female
# 3      male
# 4    female
# Name: sex, dtype: object

# %%
df.sex == 'male'
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# Name: sex, dtype: bool

# %%
df[df['sex'] == 'female']
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#   age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0  29      0      0   24160  211.3375       B5        S    2    ?
# 2   2      1      2  113781    151.55  C22 C26        S    ?    ?
# 4  25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# 2  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
dead_females = titanic[(titanic['survived'] == 0) & (titanic['sex'] == 'female')]

# %%
dead_females.set_index('name')
# Out:
#                                                     pclass  survived     sex  \
# name
# Allison, Miss. Helen Loraine                             1         0  female
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)          1         0  female
# Evans, Miss. Edith Corse                                 1         0  female
# Isham, Miss. Ann Elizabeth                               1         0  female
# Straus, Mrs. Isidor (Rosalie Ida Blun)                   1         0  female
# ...                                                    ...       ...     ...
# Vander Planke, Miss. Augusta Maria                       3         0  female
# Vander Planke, Mrs. Julius (Emelia Maria Vandem...       3         0  female
# Vestrom, Miss. Hulda Amanda Adolfina                     3         0  female
# Zabour, Miss. Hileni                                     3         0  female
# Zabour, Miss. Thamine                                    3         0  female
#
# ...

# %%
dead_females = dead_females[dead_females['age'] != '?']

# %%
dead_females.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96 entries, 937 to 807
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     96 non-null     int64
#  1   survived   96 non-null     int64
#  2   name       96 non-null     object
#  3   sex        96 non-null     object
#  4   age        96 non-null     object
#  5   sibsp      96 non-null     int64
#  6   parch      96 non-null     int64
#  7   ticket     96 non-null     object
#  8   fare       96 non-null     object
#  9   cabin      96 non-null     object
#  10  embarked   96 non-null     object
#  11  boat       96 non-null     object
#  12  body       96 non-null     object
#  13  home.dest  96 non-null     object
# dtypes: int64(4), object(10)
# memory usage: 11.2+ KB

# %%
dead_females
# Out:
#       pclass  survived                                  name     sex age  \
# 937        3         0          Klasen, Miss. Gertrud Emilia  female   1
# 828        3         0           Goodwin, Miss. Jessie Allis  female  10
# 1265       3         0             Van Impe, Miss. Catharina  female  10
# 628        3         0     Andersson, Miss. Sigrid Elisabeth  female  11
# 1279       3         0  Vestrom, Miss. Hulda Amanda Adolfina  female  14
# ...      ...       ...                                   ...     ...  ..
# 1099       3         0         Palsson, Miss. Torborg Danira  female   8
# 1208       3         0                    Skoog, Miss. Mabel  female   9
# 679        3         0               Boulos, Miss. Nourelain  female   9
# 627        3         0  Andersson, Miss. Ingeborg Constanzia  female   9
# 807        3         0      Ford, Miss. Robina Maggie 'Ruby'  female   9
#
#       sibsp  parch      ticket     fare cabin embarked boat body  \
# ...

# %%
survivors = titanic[titanic['survived'] == 1]

# %%
survivors
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 5          1         1                              Anderson, Mr. Harry
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1261       3         1                           Turkula, Mrs. (Hedwig)
# 1277       3         1                             Vartanian, Mr. David
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked   boat  \
# ...

# %%
first_and_second_class = titanic[titanic['pclass'] != 3]

# %%
third_class = titanic[titanic['pclass'] == 3]

# %%
first_and_second_class
# Out:
#      pclass  survived                                             name  \
# 0         1         1                    Allen, Miss. Elisabeth Walton
# 1         1         1                   Allison, Master. Hudson Trevor
# 2         1         0                     Allison, Miss. Helen Loraine
# 3         1         0             Allison, Mr. Hudson Joshua Creighton
# 4         1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ..      ...       ...                                              ...
# 595       2         0                   Wheeler, Mr. Edwin 'Frederick'
# 596       2         1                            Wilhelms, Mr. Charles
# 597       2         1                     Williams, Mr. Charles Eugene
# 598       2         1                             Wright, Miss. Marion
# 599       2         0           Yrois, Miss. Henriette ('Mrs Harbeck')
#
#         sex     age  sibsp  parch         ticket      fare    cabin embarked  \
# ...

# %%
third_class
# Out:
#       pclass  survived                              name     sex   age  sibsp  \
# 600        3         0               Abbing, Mr. Anthony    male    42      0
# 601        3         0     Abbott, Master. Eugene Joseph    male    13      0
# 602        3         0       Abbott, Mr. Rossmore Edward    male    16      1
# 603        3         1  Abbott, Mrs. Stanton (Rosa Hunt)  female    35      1
# 604        3         1       Abelseth, Miss. Karen Marie  female    16      0
# ...      ...       ...                               ...     ...   ...    ...
# 1304       3         0              Zabour, Miss. Hileni  female  14.5      1
# 1305       3         0             Zabour, Miss. Thamine  female     ?      1
# 1306       3         0         Zakarian, Mr. Mapriededer    male  26.5      0
# 1307       3         0               Zakarian, Mr. Ortin    male    27      0
# 1308       3         0                Zimmerman, Mr. Leo    male    29      0
#
# ...

# %%
houses.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
expensive_houses = houses[houses['price'] > 5000000]
expensive_houses.sort_values('price', ascending=False)
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 7252  6762700020  20141013T000000  7700000.0         6       8.00
# 3914  9808700762  20140611T000000  7062500.0         5       4.50
# 9254  9208900037  20140919T000000  6885000.0         6       7.75
# 4411  2470100110  20140804T000000  5570000.0         5       5.75
# 1448  8907500070  20150413T000000  5350000.0         5       5.00
# 1315  7558700030  20150413T000000  5300000.0         6       6.00
# 1164  1247600105  20141020T000000  5110800.0         5       5.25
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7252        12050     27600     2.5           0     3  ...     13        8570
# 3914        10040     37325     2.0           1     2  ...     11        7680
# 9254         9890     31374     2.0           0     4  ...     13        8860
# 4411         9200     35069     2.0           0     0  ...     13        6200
# ...

# %%
five_to_seven_bedrooms = houses[houses['bedrooms'].between(5,7)]

# %%
five_to_seven_bedrooms.sort_values('price')
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 15810  7129304540  20141220T000000   133000.0         5       2.00
# 5577   8857600780  20141003T000000   158550.0         5       1.50
# 2810   4131500140  20150212T000000   175000.0         5       1.75
# 3540   1823049202  20140610T000000   175000.0         6       1.50
# 12338  5132000140  20140618T000000   175000.0         6       1.00
# ...           ...              ...        ...       ...        ...
# 1448   8907500070  20150413T000000  5350000.0         5       5.00
# 4411   2470100110  20140804T000000  5570000.0         5       5.75
# 9254   9208900037  20140919T000000  6885000.0         6       7.75
# 3914   9808700762  20140611T000000  7062500.0         5       4.50
# 7252   6762700020  20141013T000000  7700000.0         6       8.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15810         1430      5600     1.5           0     0  ...      6
# ...

# %%
five_to_seven_bedrooms['bedrooms'].value_counts()
# Out:
# 5    1601
# 6     272
# 7      38
# Name: bedrooms, dtype: int64

# %%
top_graded_houses = houses[houses['grade'].between(11,13)].sort_values('grade')
top_graded_houses
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 14840  2424059018  20140612T000000  1070000.0         4       2.50
# 14821  7525950180  20140701T000000  1060000.0         4       2.50
# 14774  9412400220  20140710T000000  1612500.0         4       2.75
# 14669  4139430910  20141021T000000   935000.0         4       3.25
# ...           ...              ...        ...       ...        ...
# 7252   6762700020  20141013T000000  7700000.0         6       8.00
# 13411  2426039123  20150130T000000  2415000.0         5       4.75
# 19017  2303900100  20140911T000000  3800000.0         3       4.25
# 14556  2303900035  20140611T000000  2888000.0         5       6.25
# 6041   1725059316  20141120T000000  2385000.0         4       4.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 5             5420    101930     1.0           0     0  ...     11
# ...

# %%
top_graded_houses['grade'].value_counts()
# Out:
# 11    399
# 12     90
# 13     13
# Name: grade, dtype: int64

# %%
top_graded_houses.sort_index()
# Out:
#                   id             date      price  bedrooms  bathrooms  \
# yr_built
# 1902      1346300035  20140626T000000  1990000.0         5       3.00
# 1904      1346300150  20141020T000000  3300000.0         8       4.00
# 1906      1338800425  20150304T000000  2140000.0         6       4.00
# 1906      5249800010  20141203T000000  2725000.0         4       4.25
# 1909      2397101606  20141208T000000  2630000.0         6       4.75
# ...              ...              ...        ...       ...        ...
# 2014      2154970020  20140703T000000  2351960.0         4       4.25
# 2014      2525049148  20141007T000000  3418800.0         5       5.00
# 2014      1561750040  20141224T000000  1375000.0         5       4.50
# 2015      2424059174  20150508T000000  1999950.0         4       3.25
# 2015      6600000050  20150310T000000  1698000.0         4       3.50
#
#           sqft_living  sqft_lot  floors  waterfront  view  condition  grade  \
# yr_built
# ...

# %%
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
netflix.set_index('title', inplace=True)

# %%
netflix.head()
# Out:
#                       show_id     type         director  \
# title
# Dick Johnson Is Dead       s1    Movie  Kirsten Johnson
# Blood & Water              s2  TV Show              NaN
# Ganglands                  s3  TV Show  Julien Leclercq
# Jailbirds New Orleans      s4  TV Show              NaN
# Kota Factory               s5  TV Show              NaN
#
#                                                                     cast  \
# title
# Dick Johnson Is Dead                                                 NaN
# Blood & Water          Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# Ganglands              Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# Jailbirds New Orleans                                                NaN
# Kota Factory           Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
#
#                              country          date_added  release_year rating  \
# title
# Dick Johnson Is Dead   United States  September 25, 2021          2020  PG-13
# ...

# %%
mature_ratings = netflix[netflix['rating'].isin(['TV-MA', 'R'])]

# %%
mature_ratings
# Out:
#                       show_id     type                 director  \
# title
# Blood & Water              s2  TV Show                      NaN
# Ganglands                  s3  TV Show          Julien Leclercq
# Jailbirds New Orleans      s4  TV Show                      NaN
# Kota Factory               s5  TV Show                      NaN
# Midnight Mass              s6  TV Show            Mike Flanagan
# ...                       ...      ...                      ...
# Young Adult             s8792    Movie            Jason Reitman
# Zed Plus                s8799    Movie  Chandra Prakash Dwivedi
# Zinzana                 s8802    Movie          Majid Al Ansari
# Zodiac                  s8803    Movie            David Fincher
# Zombieland              s8805    Movie          Ruben Fleischer
#
#                                                                     cast  \
# title
# Blood & Water          Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...

# %%
cheap_waterfront_homes = houses[(houses['waterfront'] == 1) & (houses['price'] <= 500000)]

# %%
cheap_waterfront_homes.sort_values('price', ascending=False)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 13525  2013802060  20140927T000000  500000.0         2       1.00
# 1949   1922039062  20150420T000000  480000.0         2       1.50
# 14827  2423029009  20140617T000000  465000.0         2       2.00
# 3829   8550001515  20141001T000000  429592.0         2       2.75
# 8450    121039042  20150313T000000  425000.0         3       2.75
# 8277    221029019  20150428T000000  400000.0         3       2.50
# 19002  5216200090  20140616T000000  385000.0         2       1.00
# 18848  7631800110  20140918T000000  380000.0         3       2.50
# 264    2123039032  20141027T000000  369900.0         1       0.75
# 11556  2013802030  20140911T000000  357000.0         3       2.00
# 6102    222029026  20140917T000000  340000.0         2       0.75
# 16570  2923039243  20141113T000000  340000.0         4       1.00
# 1168   3523029041  20141009T000000  290000.0         2       0.75
# ...

# %%
great_view_and_highly_rated_homes = houses[(houses['view'] == 4) & (houses['grade'] > 10)]

# %%
great_view_and_highly_rated_homes.sort_values('grade', ascending=False)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 9254   9208900037  20140919T000000  6885000.0         6       7.75
# 19017  2303900100  20140911T000000  3800000.0         3       4.25
# 14556  2303900035  20140611T000000  2888000.0         5       6.25
# 540     622049114  20150218T000000  2125000.0         3       2.50
# 12872  2424049029  20140529T000000  3100000.0         6       4.25
# 10465   333100295  20141124T000000  3120000.0         3       3.50
# 11402  3426049284  20140819T000000  2300000.0         4       3.25
# 1164   1247600105  20141020T000000  5110800.0         5       5.25
# 11829  4139420640  20141030T000000  1785000.0         4       3.50
# 12777  1225069038  20140505T000000  2280000.0         7       8.00
# 13528  3025059124  20140828T000000  3168750.0         5       3.50
# 7269   4139470010  20141006T000000  1615000.0         4       3.25
# 15482   624069108  20140812T000000  3200000.0         4       3.25
# ...

# %%
built_or_renovatd_after_2014 = houses[(houses['yr_built'] >= 2014) | (houses['yr_renovated'] >= 2014)]

# %%
built_or_renovatd_after_2014
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 42     7203220400  20140707T000000  861990.0         5       2.75
# 63     9528102996  20141207T000000  549000.0         3       1.75
# 133    8929000270  20140512T000000  453246.0         3       2.50
# 139    2767603505  20140507T000000  519950.0         3       2.25
# 211    1025049114  20140717T000000  625504.0         3       2.25
# ...           ...              ...       ...       ...        ...
# 21598  8956200760  20141013T000000  541800.0         4       2.50
# 21602   844000965  20140626T000000  224000.0         3       1.75
# 21604  9834201367  20150126T000000  429000.0         3       2.00
# 21605  3448900210  20141014T000000  610685.0         4       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 42            3595      5639     2.0           0     0  ...      9
# ...

# %%
netflix = pd.read_csv('data/netflix_titles.csv', sep='|', index_col=0)

# %%
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
fincher = netflix['director'] == 'David Fincher'
scorsese = netflix['director'] == 'Martin Scorsese'
recent = netflix['release_year'] > 2015
netflix[(fincher | scorsese) & recent]
# Out:
#      show_id   type                                              title  \
# 1595   s1596  Movie                                               MANK
# 3227   s3228  Movie                                       The Irishman
# 3759   s3760  Movie  Rolling Thunder Revue: A Bob Dylan Story by Ma...
#
#              director                                               cast  \
# 1595    David Fincher  Gary Oldman, Amanda Seyfried, Charles Dance, L...
# 3227  Martin Scorsese  Robert De Niro, Al Pacino, Joe Pesci, Harvey K...
# 3759  Martin Scorsese  Bob Dylan, Allen Ginsberg, Joan Baez, Patti Sm...
#
#             country         date_added  release_year rating duration  \
# 1595  United States   December 4, 2020          2020      R  133 min
# 3227  United States  November 27, 2019          2019      R  209 min
# 3759  United States      June 12, 2019          2019  TV-MA  142 min
#
#                             listed_in  \
# 1595       Dramas, Independent Movies
# ...

# %%
df = titanic.head()

# %%
women = df.sex == 'female'

# %%
women
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# Name: sex, dtype: bool

# %%
~women
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# Name: sex, dtype: bool

# %%
df[women]
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#   age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0  29      0      0   24160  211.3375       B5        S    2    ?
# 2   2      1      2  113781    151.55  C22 C26        S    ?    ?
# 4  25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# 2  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
df[~women]
# Out:
#    pclass  survived                                  name   sex     age  \
# 1       1         1        Allison, Master. Hudson Trevor  male  0.9167
# 3       1         0  Allison, Mr. Hudson Joshua Creighton  male      30
#
#    sibsp  parch  ticket    fare    cabin embarked boat body  \
# 1      1      2  113781  151.55  C22 C26        S   11    ?
# 3      1      2  113781  151.55  C22 C26        S    ?  135
#
#                          home.dest
# 1  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON

# %%
newly_built = houses['yr_built'] >= 2014
newly_renovated = houses['yr_renovated'] >= 2014
recent_homes = newly_built | newly_renovated

# %%
houses[~recent_homes].sort_values('yr_built', ascending=False)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 20547  3278606050  20150401T000000  362500.0         3       3.50
# 20886  8956200530  20140805T000000  457000.0         4       2.50
# 902    2296500136  20140509T000000  839900.0         4       3.50
# 21482  4216500110  20140515T000000  819995.0         5       2.75
# 21318  7853360470  20150417T000000  641000.0         5       3.50
# ...           ...              ...       ...       ...        ...
# 19063  1702901340  20140613T000000  718500.0         3       2.00
# 498    9274202270  20140818T000000  625000.0         2       1.50
# 5928   1972201856  20140507T000000  526000.0         2       2.00
# 11251   625100004  20150317T000000  450000.0         3       2.00
# 1780   2264500890  20140508T000000  712000.0         3       1.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 20547         1710      2212     2.0           0     0  ...      7
# ...

# %%
no_cast_or_directors = netflix[(netflix['director'].isna()) & (netflix['cast'].isna())]

# %%
no_cast_or_directors
# Out:
#      show_id     type                                title director cast  \
# 3         s4  TV Show                Jailbirds New Orleans      NaN  NaN
# 10       s11  TV Show  Vendetta: Truth, Lies and The Mafia      NaN  NaN
# 14       s15  TV Show      Crime Stories: India Detectives      NaN  NaN
# 66       s67  TV Show        Raja Rasoi Aur Anya Kahaniyan      NaN  NaN
# 69       s70  TV Show       Stories by Rabindranath Tagore      NaN  NaN
# ...      ...      ...                                  ...      ...  ...
# 8605   s8606  TV Show                            Top Grier      NaN  NaN
# 8609   s8610  TV Show                               Towies      NaN  NaN
# 8700   s8701  TV Show                    Wartime Portraits      NaN  NaN
# 8755   s8756  TV Show                    Women Behind Bars      NaN  NaN
# 8803   s8804  TV Show                          Zombie Dumb      NaN  NaN
#
#             country          date_added  release_year rating   duration  \
# ...

# %%
houses[houses['price'] > 3000000]['zipcode'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>
