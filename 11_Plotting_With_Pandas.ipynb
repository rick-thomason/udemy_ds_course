# %% [markdown]
# # Plotting With Pandas (and matplotlib)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
titanic = pd.read_csv("data/titanic.csv")
titanic["age"] = pd.to_numeric(titanic["age"], errors="coerce")

# %%
houses = pd.read_csv("data/kc_house_data.csv")

# %%
ufos = pd.read_csv("data/nuforc_reports.csv", parse_dates=['date_time', "posted"])

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-bright')

# %%
houses[['sqft_living', 'sqft_lot']].sort_values('sqft_living', ascending=False).head(10).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
titanic['sex'].value_counts().plot(
    kind='bar',
    title='Passengers By Sex',
    figsize=(8,6)
    )
# Out:
# <AxesSubplot:title={'center':'Passengers By Sex'}>

# %%
titanic['sex'].value_counts().plot(
    kind='bar',
    figsize=(8,6)
    )
plt.title('Passengers By Sex', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Passengers By Sex')

# %%
ufos.head()
# Out:
#                                              summary        city state  \
# 0  My wife was driving southeast on a fairly popu...     Chester    VA
# 1  I think that I may caught a UFO on the NBC Nig...  Rocky Hill    CT
# 2  I woke up late in the afternoon 3:30-4pm. I we...         NaN   NaN
# 3  I was driving towards the intersection of fall...      Ottawa    ON
# 4  In Peoria Arizona, I saw a cigar shaped craft ...      Peoria    NY
#
#             date_time     shape     duration  \
# 0 2019-12-12 18:43:00     light    5 seconds
# 1 2019-03-22 18:30:00    circle  3-5 seconds
# 2                 NaT       NaN          NaN
# 3 2019-04-17 02:00:00  teardrop   10 seconds
# 4 2009-03-15 18:00:00     cigar    2 minutes
#
#                                                stats  \
# 0  Occurred : 12/12/2019 18:43  (Entered as : 12/...
# 1  Occurred : 3/22/2019 18:30  (Entered as : 03/2...
# 2  Occurred : 4/1/2019 15:45  (Entered as : April...
# ...

# %%
ufos['month'] = ufos['date_time'].dt.month

# %%
ufos.head()
# Out:
#                                              summary        city state  \
# 0  My wife was driving southeast on a fairly popu...     Chester    VA
# 1  I think that I may caught a UFO on the NBC Nig...  Rocky Hill    CT
# 2  I woke up late in the afternoon 3:30-4pm. I we...         NaN   NaN
# 3  I was driving towards the intersection of fall...      Ottawa    ON
# 4  In Peoria Arizona, I saw a cigar shaped craft ...      Peoria    NY
#
#             date_time     shape     duration  \
# 0 2019-12-12 18:43:00     light    5 seconds
# 1 2019-03-22 18:30:00    circle  3-5 seconds
# 2                 NaT       NaN          NaN
# 3 2019-04-17 02:00:00  teardrop   10 seconds
# 4 2009-03-15 18:00:00     cigar    2 minutes
#
#                                                stats  \
# 0  Occurred : 12/12/2019 18:43  (Entered as : 12/...
# 1  Occurred : 3/22/2019 18:30  (Entered as : 03/2...
# 2  Occurred : 4/1/2019 15:45  (Entered as : April...
# ...

# %%
sightings = ufos.month.value_counts().sort_index()
sightings.plot(kind='bar', title='UFO Sightings By Month')
plt.show()

# %%
months_dict = {1: "Jan", 2: "Feb", 3: "Mar", 4: "Apr", 5: "May", 6: "Jun", 7:"Jul", 8: "Aug", 9:"Sep", 10: "Oct", 11: "Nov", 12: "Dec"}
sightings.rename(months_dict, inplace=True)

# %%
sightings.plot(kind='bar',
xlabel='Month',
ylabel='Number of Sightings',
fontsize=15)
plt.title('UFO Sightings By Month',fontsize=30)
plt.show()

# %%
salaries = pd.read_csv('data/Salaries.csv', low_memory=False)
salaries.columns = [x.lower() for x in salaries.columns]

# %%
salaries.head()
# Out:
#    id       employeename                                        jobtitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      basepay overtimepay   otherpay benefits   totalpay  totalpaybenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# 3    77916.0    56120.71   198306.9      NaN  332343.61         332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19         326373.19
#
#    year  notes         agency status
# 0  2011    NaN  San Francisco    NaN
# ...

# %%
salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                148654 non-null  int64
#  1   employeename      148654 non-null  object
#  2   jobtitle          148654 non-null  object
#  3   basepay           148049 non-null  object
#  4   overtimepay       148654 non-null  object
#  5   otherpay          148654 non-null  object
#  6   benefits          112495 non-null  object
#  7   totalpay          148654 non-null  float64
#  8   totalpaybenefits  148654 non-null  float64
#  9   year              148654 non-null  int64
#  10  notes             0 non-null       float64
#  11  agency            148654 non-null  object
#  12  status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
salaries['basepay'] = pd.to_numeric(salaries['basepay'], errors='coerce').fillna(0)
salaries['overtimepay'] = pd.to_numeric(salaries['overtimepay'], errors='coerce').fillna(0)
salaries['otherpay'] = pd.to_numeric(salaries['otherpay'], errors='coerce').fillna(0)
salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                148654 non-null  int64
#  1   employeename      148654 non-null  object
#  2   jobtitle          148654 non-null  object
#  3   basepay           148654 non-null  float64
#  4   overtimepay       148654 non-null  float64
#  5   otherpay          148654 non-null  float64
#  6   benefits          112495 non-null  object
#  7   totalpay          148654 non-null  float64
#  8   totalpaybenefits  148654 non-null  float64
#  9   year              148654 non-null  int64
#  10  notes             0 non-null       float64
#  11  agency            148654 non-null  object
#  12  status            38119 non-null   object
# dtypes: float64(6), int64(2), object(5)
# memory usage: 14.7+ MB

# %%
df = salaries[['employeename', 'basepay', 'overtimepay', 'otherpay']]

# %%
df.set_index('employeename')

# %%
df.head(10).plot(kind='bar')
plt.show()

# %%
df.head(10).plot.bar(stacked=True)
plt.show()

# %%
df['basepay'].sort_values(ascending=False).head().plot.bar(ylabel='Base Pay', xlabel='Employee Name', title='Salaries')
# Out:
# <AxesSubplot:title={'center':'Salaries'}, xlabel='Employee Name', ylabel='Base Pay'>

# %%
df.sort_values('overtimepay', ascending=False).head().plot.barh(stacked=True, figsize=(10,5))
plt.title('Highest Paid Employees', fontsize=20)
plt.xlabel('Dollars', fontsize=15)
plt.ylabel('Employee', fontsize=15)
plt.show()

# %%
df['basepay'].plot.hist(bins=200, figsize=(10,8))
plt.show()

# %%
df.hist(figsize=(16,8))
plt.show()

# %% [markdown]
# ## Box Plots

# %%
df.plot.box(figsize=(14,6))
plt.show()

# %%
houses.bedrooms.value_counts().sort_index(ascending=False)
# Out:
# 33       1
# 11       1
# 10       3
# 9        6
# 8       13
# 7       38
# 6      272
# 5     1601
# 4     6882
# 3     9824
# 2     2760
# 1      199
# 0       13
# Name: bedrooms, dtype: int64

# %%
houses.bedrooms.plot.box(figsize=(8,8))
# Out:
# <AxesSubplot:>

# %%
houses.bedrooms.plot.box(figsize=(8,8), showfliers=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Line Plots

# %%
ufos['year'] = ufos['date_time'].dt.year
ufos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87891 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  datetime64[ns]
#  4   shape           85627 non-null  object
#  5   duration        84954 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  datetime64[ns]
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
#  12  month           86938 non-null  float64
#  13  year            86938 non-null  float64
# dtypes: datetime64[ns](2), float64(4), object(8)
# memory usage: 9.4+ MB

# %%
ufos.year.value_counts().sort_index().plot()
plt.show()

# %% [markdown]
# ## Scatter Plots

# %%
houses.plot.scatter(x='bedrooms', y='bathrooms')
plt.show()

# %%
ufos[ufos['state'] == 'CA']['year'].value_counts().sort_index().plot(label='CA', figsize=(10,5), lw=5)
ufos[ufos['state'] == 'TX']['year'].value_counts().sort_index().plot(label='TX', lw=5)
plt.legend(shadow=True, loc='upper left')
plt.title('UFO Sightings By State', fontsize=20)
plt.xlabel('Year', fontsize=15)
# Out:
# Text(0.5, 0, 'Year')

# %%
ufos['shape'].value_counts()
# Out:
# light        18230
# circle       10130
# triangle      7910
# fireball      7095
# unknown       6182
# sphere        6065
# other         5749
# disk          4522
# oval          3857
# formation     2842
# changing      2112
# cigar         1990
# flash         1675
# rectangle     1597
# cylinder      1374
# diamond       1273
# chevron        953
# teardrop       767
# egg            666
# cone           349
# cross          289
# Name: shape, dtype: int64

# %%
ufos[ufos['shape'] == 'light'].year.value_counts().sort_index().plot(label='light', figsize=(10,8), lw=3)
ufos[ufos['shape'] == 'circle'].year.value_counts().sort_index().plot(label='circle', lw=3)
ufos[ufos['shape'] == 'fireball'].year.value_counts().sort_index().plot(label='fireball', lw=3)
ufos[ufos['shape'] == 'triangle'].year.value_counts().sort_index().plot(label='triangle', lw=3)
ufos[ufos['shape'] == 'formation'].year.value_counts().sort_index().plot(label='formation', lw=3)
plt.title('UFO Sightings By Shape (2000-2018)', fontsize=20)
plt.xlim(2000,2018)
plt.legend(shadow=True)
plt.show()

# %% [markdown]
# ## Subplots

# %%
df.plot.hist(subplots=True, figsize=(8,6), sharex=False)
plt.tight_layout()
plt.show()

# %%
axs = df.plot.hist(subplots=True, figsize=(14,4), sharex=False, layout=(1,3), bins=30)
plt.tight_layout()

axs[0][0].set_xlim(0, 250000)
axs[0][2].set_xlim(0, 20000)
plt.show()

# %%
ufos['year'].value_counts().sort_index().plot()
# Out:
# <AxesSubplot:>

# %%
fig, axs = plt.subplots(1,2)
ufos['year'].value_counts().sort_index().plot(figsize=(15,6), ax=axs[0], lw=3)
axs[0].set_title('Sightings By Year')
ufos['month'].value_counts().sort_index().rename(months_dict).plot.bar(ax=axs[1])
axs[1].set_title('Sightings By Month')

plt.show()

# %%
fig, axs = plt.subplots(2,3, figsize=(15,6), dpi=100)
fig.suptitle('UFO Sightings By Month', fontsize=20)
fig.tight_layout(pad=2)

ufos[ufos['year'] == 2014].month.value_counts().sort_index().rename(months_dict).plot.bar(ax=axs[0][0], title='2014')
ufos[ufos['year'] == 2015].month.value_counts().sort_index().rename(months_dict).plot.bar(ax=axs[0][1], title='2015')
ufos[ufos['year'] == 2016].month.value_counts().sort_index().rename(months_dict).plot.bar(ax=axs[0][2], title='2016')
ufos[ufos['year'] == 2017].month.value_counts().sort_index().rename(months_dict).plot.bar(ax=axs[1][0], title='2017')
ufos[ufos['year'] == 2018].month.value_counts().sort_index().rename(months_dict).plot.bar(ax=axs[1][1], title='2018')
ufos[ufos['year'] == 2019].month.value_counts().sort_index().rename(months_dict).plot.bar(ax=axs[1][2], title='2019')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Manual Subplots

# %% [markdown]
# ## Savefig()
